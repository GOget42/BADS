# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raphael/flights_final.csv')

# %%
df
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015      1    1            4        AA           1112      N3LAAA
# 1       2015      1    1            4        DL           1173      N826DN
# 2       2015      1    1            4        DL           2336      N958DN
# 3       2015      1    1            4        UA           1197      N78448
# 4       2015      1    1            4        NK            214      N632NK
# ...      ...    ...  ...          ...       ...            ...         ...
# 460385  2015     12   31            4        UA           1204      N476UA
# 460386  2015     12   31            4        DL           1354      N1607B
# 460387  2015     12   31            4        F9            420      N947FR
# 460388  2015     12   31            4        UA           1205      N87527
# 460389  2015     12   31            4        AA            219      N3LYAA
#
# ...

# %%
df2 = pd.read_csv('../data/raphael/flights.csv')
# Out:
# C:\Users\ogetg\AppData\Local\Temp\ipykernel_18152\3104773252.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('../data/raphael/flights.csv')

# %%
df2
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
df3 = pd.read_csv('../data/clean/final_df.csv')

# %%
df3
# Out:
#         DEPARTURE_DELAY  TAXI_OUT  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  \
# 0                   0.0       0.0           150.0           0.0       0.0
# 1                  -1.0      31.0           128.0         137.0      97.0
# 2                  -4.0      16.0           136.0         147.0     121.0
# 3                  12.0      22.0           335.0         332.0     300.0
# 4                  -5.0      32.0           130.0         169.0      98.0
# ...                 ...       ...             ...           ...       ...
# 460385              3.0      14.0           265.0         241.0     223.0
# 460386              0.0      15.0            96.0          77.0      57.0
# 460387             -1.0      17.0           252.0         241.0     217.0
# 460388             -4.0      18.0           279.0         284.0     225.0
# 460389             -6.0      13.0           222.0         202.0     184.0
#
#         DISTANCE  TAXI_IN  ARRIVAL_DELAY  DIVERTED  CANCELLED  ...  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460390 entries, 0 to 460389
# Data columns (total 100 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   DEPARTURE_DELAY                                                       460390 non-null  float64
#  1   TAXI_OUT                                                              460390 non-null  float64
#  2   SCHEDULED_TIME                                                        460390 non-null  float64
#  3   ELAPSED_TIME                                                          460390 non-null  float64
#  4   AIR_TIME                                                              460390 non-null  float64
#  5   DISTANCE                                                              460390 non-null  int64
# ...

# %%
airports = pd.read_csv('../data/raw/airports.csv')

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  322 non-null    object
#  1   AIRPORT    322 non-null    object
#  2   CITY       322 non-null    object
#  3   STATE      322 non-null    object
#  4   COUNTRY    322 non-null    object
#  5   LATITUDE   319 non-null    float64
#  6   LONGITUDE  319 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 17.7+ KB

# %%
airport_codes = ["DFW", "DEN", "IAH", "ATL", "LGA", "LAX", "LAS", "PHX", "SFO"]

# %%
set(airports['IATA_CODE'].unique()) - (set(airports['IATA_CODE'].unique())-set(airport_codes))
# Out:
# {'ATL', 'DEN', 'DFW', 'IAH', 'LAS', 'LAX', 'LGA', 'PHX', 'SFO'}

# %%
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE_x', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY', 'date', 'IATA_CODE_x',
#        'AIRLINE_y', 'IATA_CODE_y', 'Origin_AIRPORT', 'Origin_CITY',
#        'Origin_STATE', 'Origin_COUNTRY', 'Origin_LATITUDE', 'Origin_LONGITUDE',
#        'Destination_IATA_CODE', 'Destination_AIRPORT', 'Destination_CITY',
#        'Destination_STATE', 'Destination_COUNTRY', 'Destination_LATITUDE',
#        'Destination_LONGITUDE', 'CANCELLATION_DESCRIPTION',
# ...

# %%
df['IATA_CODE_x'].unique()
# Out:
# array(['AA', 'DL', 'UA', 'NK', 'US', 'OO', 'WN', 'F9', 'VX', 'EV', 'MQ',
#        'B6'], dtype=object)

# %%
df['IATA_CODE_y'].unique()
# Out:
# array(['SFO', 'LAS', 'DEN', 'LAX', 'PHX', 'ORD', 'DFW', 'IAH', 'LGA',
#        'ATL'], dtype=object)

# %%
df['Destination_IATA_CODE'].unique()
# Out:
# array(['DFW', 'ATL', 'IAH', 'ORD', 'PHX', 'DEN', 'LAX', 'LGA', 'SFO',
#        'LAS'], dtype=object)

# %%
["ATL", "DEN", "DFW", "IAH", "LAS", "LAX", "LGA", "ORD", "PHX", "SFO"]
